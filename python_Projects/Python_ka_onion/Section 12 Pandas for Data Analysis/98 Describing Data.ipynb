# %%
import pandas as pd

# %%
customer_churn_data = pd.read_csv("customer_churn_data.csv")
customer_churn_data.head()
# Out:
#   customer_id  age gender  tenure_months  monthly_charges  total_charges  \
# 0        C001   45      M             24             70.5         1692.0
# 1        C002   29      F              6             89.9          539.4
# 2        C003   61      M             48             55.3         2654.4
# 3        C004   34      F             12             95.1         1141.2
# 4        C005   52      M             36             60.0         2160.0
#
#     contract_type    payment_method internet_service  support_calls  churn
# 0        One year       Credit card            Fiber              1      0
# 1  Month-to-month  Electronic check            Fiber              3      1
# 2        Two year     Bank transfer              DSL              0      0
# 3  Month-to-month  Electronic check            Fiber              4      1
# 4        One year       Credit card              DSL              1      0

# %%
customer_churn_data.dtypes
# Out:
# customer_id             str
# age                   int64
# gender                  str
# tenure_months         int64
# monthly_charges     float64
# total_charges       float64
# contract_type           str
# payment_method          str
# internet_service        str
# support_calls         int64
# churn                 int64
# dtype: object

# %%
customer_churn_data.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'tenure_months', 'monthly_charges',
#        'total_charges', 'contract_type', 'payment_method', 'internet_service',
#        'support_calls', 'churn'],
#       dtype='str')

# %%
columsn = customer_churn_data.columns
columsn
# Out:
# Index(['customer_id', 'age', 'gender', 'tenure_months', 'monthly_charges',
#        'total_charges', 'contract_type', 'payment_method', 'internet_service',
#        'support_calls', 'churn'],
#       dtype='str')

# %%
customer_churn_data.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
customer_churn_data.describe()
# Out:
#              age  tenure_months  monthly_charges  total_charges  \
# count   6.000000       6.000000         6.000000       6.000000
# mean   43.666667      21.500000        78.383333    1414.250000
# std    11.724618      17.840964        18.925794     922.613357
# min    29.000000       3.000000        55.300000     298.500000
# 25%    35.750000       7.500000        62.625000     689.850000
# 50%    43.000000      18.000000        80.200000    1416.600000
# 75%    50.250000      33.000000        93.800000    2043.000000
# max    61.000000      48.000000        99.500000    2654.400000
#
#        support_calls     churn
# count       6.000000  6.000000
# mean        2.333333  0.500000
# std         1.966384  0.547723
# min         0.000000  0.000000
# 25%         1.000000  0.000000
# 50%         2.000000  0.500000
# 75%         3.750000  1.000000
# max         5.000000  1.000000

# %%
customer_churn_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       6 non-null      str
#  1   age               6 non-null      int64
#  2   gender            6 non-null      str
#  3   tenure_months     6 non-null      int64
#  4   monthly_charges   6 non-null      float64
#  5   total_charges     6 non-null      float64
#  6   contract_type     6 non-null      str
#  7   payment_method    6 non-null      str
#  8   internet_service  6 non-null      str
#  9   support_calls     6 non-null      int64
#  10  churn             6 non-null      int64
# dtypes: float64(2), int64(4), str(5)
# memory usage: 660.0 bytes

# %%
customer_churn_data.mean()  #our data contain stings error arises
# Out:
# ----------------------------------------
# TypeErrorTraceback (most recent call last)
# Cell In[9], line 1
# ----> 1 customer_churn_data.mean()  #our data contain stings error arises
#
# File C:\python_Projects\Python_ka_onion\.venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File C:\python_Projects\Python_ka_onion\.venv\Lib\site-packages\pandas\core\frame.py:14461, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   14380 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
#   14381 def mean(
#   14382     self,
#    (...)  14386     **kwargs,
#   14387 ) -> Series | Any:
#   14388     """
#   14389     Return the mean of the values over the requested axis.
#   14390
#    (...)  14459     dtype: float64
#   14460     """
# > 14461     result = super().mean(
#   14462         axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#   14463     )
#   14464     if isinstance(result, Series):
#   14465         result = result.__finalize__(self, method="mean")
#
# File C:\python_Projects\Python_ka_onion\.venv\Lib\site-packages\pandas\core\generic.py:11831, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11823 def mean(
#   11824     self,
#   11825     *,
#    (...)  11829     **kwargs,
#   11830 ) -> Series | float:
# > 11831     return self._stat_function(
#   11832         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11833     )
#
# File C:\python_Projects\Python_ka_onion\.venv\Lib\site-packages\pandas\core\generic.py:11785, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11781 nv.validate_func(name, (), kwargs)
#   11783 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11785 return self._reduce(
#   11786     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11787 )
#
# File C:\python_Projects\Python_ka_onion\.venv\Lib\site-packages\pandas\core\frame.py:13617, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   13613     df = df.T
#   13615 # After possibly _get_data and transposing, we are now in the
#   13616 #  simple case where we can use BlockManager.reduce
# > 13617 res = df._mgr.reduce(blk_func)
#   13618 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   13619 out.name = None
#
# File C:\python_Projects\Python_ka_onion\.venv\Lib\site-packages\pandas\core\internals\managers.py:1656, in BlockManager.reduce(self, func)
#    1653 # If 2D, we assume that we're operating column-wise
#    1654 assert self.ndim == 2
# -> 1656 res_blocks = [blk.reduce(func) for blk in self.blocks]
#    1657 index = default_index(1)  # placeholder
#    1658 # shallow copy self.items not needed because DataFrame._reduce does a getitem
#
# File C:\python_Projects\Python_ka_onion\.venv\Lib\site-packages\pandas\core\internals\managers.py:1656, in <listcomp>(.0)
#    1653 # If 2D, we assume that we're operating column-wise
#    1654 assert self.ndim == 2
# -> 1656 res_blocks = [blk.reduce(func) for blk in self.blocks]
#    1657 index = default_index(1)  # placeholder
#    1658 # shallow copy self.items not needed because DataFrame._reduce does a getitem
#
# File C:\python_Projects\Python_ka_onion\.venv\Lib\site-packages\pandas\core\internals\blocks.py:358, in Block.reduce(self, func)
#     352 @final
#     353 def reduce(self, func) -> Block:
#     354     # We will apply the function and reshape the result into a single-row
#     355     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     356     assert self.ndim == 2
# --> 358     result = func(self.values)
#     360     if self.values.ndim == 1:
#     361         res_values = result
#
# File C:\python_Projects\Python_ka_onion\.venv\Lib\site-packages\pandas\core\frame.py:13545, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   13543     if not is_1d_only_ea_dtype(values.dtype):
#   13544         return values._reduce(name, axis=1, skipna=skipna, **kwds)
# > 13545     return values._reduce(name, skipna=skipna, keepdims=True, **kwds)
#   13546 else:
#   13547     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File C:\python_Projects\Python_ka_onion\.venv\Lib\site-packages\pandas\core\arrays\string_.py:967, in StringArray._reduce(self, name, skipna, keepdims, axis, **kwargs)
#     964         return self._from_sequence([result], dtype=self.dtype)
#     965     return result
# --> 967 raise TypeError(f"Cannot perform reduction '{name}' with string dtype")
#
# TypeError: Cannot perform reduction 'mean' with string dtype

# %% [markdown]
# You ran:
#
# omer_churn_data.mean()
#
# Here’s what you need to know 👇
#
# 1️⃣ Will this work or not? ✅ It WILL work only if all columns are numeric ❌ It WILL FAIL if even one column is text (string)
#
# That’s exactly the issue you hit earlier.
#
# 2️⃣ Safe & correct way (RECOMMENDED)
#
# Always do this 👇
#
# omer_churn_data.mean(numeric_only=True)
#
# This tells pandas:
#
# “Ignore text columns, only calculate mean on numbers”
#
# 3️⃣ Check WHY it fails (important habit)
#
# Run this:
#
# omer_churn_data.dtypes
#
# If you see:
#
# object
#
# that column is text and cannot have a mean.
#
# 4️⃣ Mean of ONE column (best for learning) omer_churn_data["monthly_charges"].mean()
#
# or
#
# omer_churn_data["churn"].mean()
#
# 👉 churn mean = churn rate
#
# 5️⃣ If churn is still text (Yes/No)
#
# Fix it once and forever:
#
# omer_churn_data["churn"] = omer_churn_data["churn"].map({"Yes": 1, "No": 0})
#
# Then:
#
# omer_churn_data.mean()
#
# 🧠 Golden rule (pin this in your head)
#
# Math → numbers only Text → clean/convert first
#
# Quick check for you
#
# Run this and tell me what you see:
#
# omer_churn_data.dtypes

# %%
customer_churn_data.mean(numeric_only=True) #Ignores text columns, only calculate mean on numbers
# Out:
# age                  43.666667
# tenure_months        21.500000
# monthly_charges      78.383333
# total_charges      1414.250000
# support_calls         2.333333
# churn                 0.500000
# dtype: float64

# %%
customer_churn_data['age']
# Out:
# 0    45
# 1    29
# 2    61
# 3    34
# 4    52
# 5    41
# Name: age, dtype: int64

# %%
customer_churn_data['total_charges']
# Out:
# 0    1692.0
# 1     539.4
# 2    2654.4
# 3    1141.2
# 4    2160.0
# 5     298.5
# Name: total_charges, dtype: float64

# %%
customer_churn_data['monthly_charges']
# Out:
# 0    70.5
# 1    89.9
# 2    55.3
# 3    95.1
# 4    60.0
# 5    99.5
# Name: monthly_charges, dtype: float64

# %%
#also we can do sum of columns values
customer_churn_data['monthly_charges'].sum()
# Out:
# np.float64(470.29999999999995)

# %%
customer_churn_data['monthly_charges'].sum()
# Out:
# np.float64(470.29999999999995)
