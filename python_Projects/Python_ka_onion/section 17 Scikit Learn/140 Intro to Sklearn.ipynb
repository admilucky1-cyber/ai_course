# %% [markdown]
# the complete Machine Learning workflow using scikit-learn. Let me break each point down in simple, practical terms, so it actually sticks.
#
# ##### 1. Entire Workflow
#
# This means understanding the full ML pipeline, not just training a model.
#
# Typical sklearn workflow:
#
# Data → Preprocessing → Model → Training → Prediction → Evaluation → Improvement → Save
#
#
# Sklearn teaches you how all these steps connect logically.
#
# ##### 2. Getting Data Ready
#
# Raw data is messy 😅 — sklearn expects clean numerical data.
#
# You learn:
#
# Handling missing values (SimpleImputer)
#
# Encoding categorical data (LabelEncoder, OneHotEncoder)
#
# Feature scaling (StandardScaler, MinMaxScaler)
#
# Train-test split
#
# Example:
#
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y)
#
#
# 👉 This step decides model success or failure.
#
# ##### 3. Choosing Machine Learning Model
#
# You select a model based on the problem:
#
# Problem	Model
# Predict number	Linear Regression
# Yes / No	Logistic Regression
# Categories	Decision Tree, SVM
# Patterns	KNN, Random Forest
#
# Example:
#
# from sklearn.linear_model import LinearRegression
# model = LinearRegression()
#
#
# Sklearn makes model selection easy.
#
# ##### 4. Fitting the Model to the Data
#
# This is where learning happens 🧠
#
# model.fit(X_train, y_train)
#
#
# What happens internally:
#
# Model adjusts weights
#
# Minimizes error
#
# Learns patterns
#
# 👉 After fit(), the model is trained.
#
# ##### 5. Making Prediction
#
# Now you use the trained model:
#
# y_pred = model.predict(X_test)
#
#
# This is the actual output you care about:
#
# House price
#
# Spam or not
#
# Disease yes/no
#
# ##### 6. Evaluating Prediction
#
# Check how good your model is.
#
# Common metrics:
#
# Accuracy
#
# Precision / Recall
#
# Mean Squared Error
#
# R² Score
#
# Example:
#
# from sklearn.metrics import accuracy_score
# accuracy_score(y_test, y_pred)
#
#
# 👉 No evaluation = blind trust ❌
#
# ##### 7. Improving Model Prediction
#
# If results are poor, you:
#
# Tune hyperparameters
#
# Try a different model
#
# Add/remove features
#
# Use cross-validation
#
# Example:
#
# from sklearn.model_selection import GridSearchCV
#
#
# This step separates beginners from ML engineers.
#
# ##### 8. Saving and Loading Model
#
# So you don’t train again every time 💾
#
# import joblib
# joblib.dump(model, "model.pkl")
# model = joblib.load("model.pkl")
#
#
# Used in:
#
# Web apps
#
# APIs
#
# Production systems
#
# Big Picture Summary 🧠
#
# Sklearn doesn’t just teach models — it teaches how ML actually works in real life.
#
# Machine Learning = data + model + evaluation + improvement
