# %% [markdown]
# # What does “Choosing an ML Model” actually mean?
#
# It means selecting the right algorithm for your problem type + data.
#
# ❌ Not “which model is best overall”
# ✅ “which model fits this problem”
#
# First question you must ask ❓
#
# What kind of problem is this?
#
# 1️⃣ Regression (predict a number)
#
# Examples:
#
# House price
#
# Temperature
#
# Salary
#
# Models to choose from:
#
# Linear Regression
#
# Ridge / Lasso
#
# Random Forest Regressor
#
# from sklearn.linear_model import LinearRegression
# model = LinearRegression()
#
# 2️⃣ Classification (predict a category / label)
#
# Examples:
#
# Spam / Not spam
#
# Disease Yes / No
#
# Pass / Fail
#
# Models:
#
# Logistic Regression
#
# Decision Tree
#
# SVM
#
# Random Forest
#
# from sklearn.linear_model import LogisticRegression
# model = LogisticRegression()
#
# 3️⃣ Clustering (no labels)
#
# Examples:
#
# Customer grouping
#
# Pattern discovery
#
# Models:
#
# KMeans
#
# DBSCAN
#
# from sklearn.cluster import KMeans
# model = KMeans(n_clusters=3)
#
# Second question ❓
#
# How much data do you have?
#
# Data Size	Good Choices
# Small	Linear / Logistic Regression
# Medium	Decision Tree, KNN
# Large	Random Forest, Gradient Boosting
# Third question ❓
#
# Is data simple or complex?
#
# Data	Model
# Linear relationship	Linear Regression
# Non-linear	Decision Tree, Random Forest
# Many features	Regularized models
# Beginner-friendly rule (VERY useful) ⭐
#
# Start simple → then go complex:
#
# Logistic / Linear Regression
#
# Decision Tree
#
# Random Forest
#
# Boosting models
#
# If a simple model works well, don’t overcomplicate.
#
# How sklearn helps here
#
# Sklearn gives:
#
# Consistent API (fit, predict)
#
# Easy model switching
#
# Built-in defaults that work well
#
# You can literally change one line and test another model:
#
# model = RandomForestClassifier()
#
# Real-world thinking (job mindset 💼)
#
# ML engineers try multiple models, compare scores, and choose the best.
#
# That’s normal and expected.
#
# One-line takeaway ✨
#
# Choosing an ML model = matching the problem + data + complexity.

# %%
import pandas as pd

# %%
heart_disease = pd.read_csv('heart_disease_300.csv')

# %%
heart_disease
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     67    1   2       122   139    1        1      168      0      2.2
# 1     57    0   0       154   232    1        2      108      0      4.1
# 2     43    0   3       107   259    0        0       84      0      4.9
# 3     71    1   2       185   166    1        2      188      1      5.7
# 4     36    0   0       138   120    1        1       98      1      1.5
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   46    1   1       115   376    0        1      171      1      0.4
# 299   74    0   1       157   197    0        1       88      0      3.6
# 300   46    0   2       108   490    1        1      151      0      3.5
# 301   30    0   0       173   294    0        0       92      1      3.5
# 302   63    0   0       186   313    1        0      152      1      3.7
#
#      slope  ca  thal  target
# 0        1   1     0       0
# 1        1   2     0       0
# 2        1   3     1       1
# 3        2   3     0       1
# 4        2   0     1       0
# ..     ...  ..   ...     ...
# 298      0   3     1       0
# 299      0   0     2       1
# 300      0   3     2       0
# 301      1   3     1       0
# 302      1   0     1       1
#
# [303 rows x 14 columns]

# %%
# create x
X = heart_disease.drop('target',axis=1)
X
# create y
Y = heart_disease['target']
Y
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      0
#       ..
# 298    0
# 299    1
# 300    0
# 301    0
# 302    1
# Name: target, Length: 303, dtype: int64

# %%
#from 140### 2 choosing  Machine Learning Model
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.get_params()
# Out:
# {'bootstrap': True,
#  'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': 'sqrt',
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'monotonic_cst': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}
