# %% [markdown]
# ## 115. Dot Product

# %%
import pandas as pd

# %%
import numpy as np

# %%
np.random.seed(seed=0)
matrix_1 = np.random.randint(10,size=(4,3))
matrix_2 = np.random.randint(10,size=(4,3))

# %%
matrix_1
# Out:
# array([[5, 0, 3],
#        [3, 7, 9],
#        [3, 5, 2],
#        [4, 7, 6]], dtype=int32)

# %%
matrix_2
# Out:
# array([[8, 8, 1],
#        [6, 7, 7],
#        [8, 1, 5],
#        [9, 8, 9]], dtype=int32)

# %% [markdown]
# ## Element wise multiplication kia hoti hai

# %%
matrix_1*matrix_1
# Out:
# array([[25,  0,  9],
#        [ 9, 49, 81],
#        [ 9, 25,  4],
#        [16, 49, 36]], dtype=int32)

# %%
matrix_1*matrix_2
# Out:
# array([[40,  0,  3],
#        [18, 49, 63],
#        [24,  5, 10],
#        [36, 56, 54]], dtype=int32)

# %%
matrix_1.dot(matrix_2) #because we have take transpose to make balance in dimensions
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 matrix_1.dot(matrix_2)
#
# ValueError: shapes (4,3) and (4,3) not aligned: 3 (dim 1) != 4 (dim 0)

# %%
matrix_1.dot(matrix_2.T) #just like we multiplied matrices in 9th and 11th class mathematics after taking transpose by swap=by changing rows of matrix into columns
# Out:
# array([[ 43,  51,  55,  72],
#        [ 89, 130,  76, 164],
#        [ 66,  67,  39,  85],
#        [ 94, 115,  69, 146]], dtype=int32)

# %%
matrix_1.shape,matrix_2.T.shape
# Out:
# ((4, 3), (3, 4))

# %% [markdown]
# # here is link for matrix multiplications ::http://matrixmultiplication.xyz/
