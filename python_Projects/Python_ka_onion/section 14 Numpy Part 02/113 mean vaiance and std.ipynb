# %% [markdown]
# # mean vaiance and std
# # 📊 Core Concepts Covered
#
# ## Mean (np.mean)
#
# The average of all elements in an array.
#
# Demonstrated with 1D and 2D arrays, including axis-specific calculations.
#
# ### Variance (np.var)
#
# Measures how far data points spread out from the mean.
#
# Shows how variance increases with more dispersed values.
#
# Examples include both population and sample variance.
#
# #### Standard Deviation (np.std)
#
# Square root of variance, giving spread in the same units as the data.
#
# Illustrated with practical examples to highlight its interpretability compared to variance.
#
# #### 🛠️ Practical Demonstrations
# Using NumPy functions directly (np.mean, np.var, np.std).
#
# Applying calculations along specific axes in multi-dimensional arrays.
#
# Comparing manual calculations with NumPy’s built-in methods to validate results.
#
# ### 🎯 Teaching Emphasis
# Clear step-by-step walkthroughs with code snippets.
#
# Focus on how these statistical measures help in understanding datasets.
#
# Reinforcement of the difference between variance and standard deviation for interpretation.

# %% [markdown]
# # 📊 Explanation of the Diagram
# Mean (Green dashed line):
# The sine wave oscillates around 0, which is its average value. This line represents the "sea level" of the wave.
#
# Variance (Orange vertical markers):
# These lines show how far each point of the sine wave is from the mean. Squaring these distances gives the variance.
#
# Small variance → gentle wave.
#
# Large variance → stormy wave.
#
# Standard Deviation (Red dotted lines):
# These lines mark Mean ± 1 SD. They show the typical spread of the sine wave from the mean.
#
# For sine, SD ≈ 0.707.
#
# This means most values lie within ±0.707 of the mean.
#
# 🛠️ Teaching Analogy
# Mean: Calm sea level.
#
# Variance: Energy of the storm (how wild the wave is).
#
# Standard Deviation: The average splash height above or below sea level.

# %% [markdown]
# ## Mean (Average)
# Formula:
#
# Mean
# =
# Sum of all values
# Number of values
# Example: For [2, 4, 6],
# Mean = (2 + 4 + 6) ÷ 3 = 4
#
# Classroom tip: Call it the "center" of the data.
#
# 🔵 Variance (Spread of Data)
# Formula:
#
# Variance
# =
# ∑
# (
# 𝑥
# 𝑖
# −
# Mean
# )
# 2
# 𝑛
# Example: For [2, 4, 6], mean = 4.
# Differences = [-2, 0, +2] → Squares = [4, 0, 4] → Variance = (4+0+4)/3 = 2.67
#
# Classroom tip: Tell students it’s "how far the data is spread out from the mean."
#
# 🔴 Standard Deviation (SD)
# Formula:
#
# SD
# =
# Variance
# Example: √2.67 ≈ 1.63
#
# Classroom tip: Explain that SD is easier to understand than variance because it’s in the same units as the data.
#
# 🛠️ NumPy Shortcuts
# np.mean(arr) → Mean
#
# np.var(arr) → Variance
#
# np.std(arr) → Standard Deviation
#
# 🎯 Teacher’s Analogy
# Mean: The "average height" of the class.
#
# Variance: How much students’ heights differ from that average.
#
# Standard Deviation: A practical measure of that difference, in centimeters (same unit as height).

# %%
#mean 
#variance
#std
import pandas as pd

# %%
import numpy as np

# %%
a1d = np.array([5,6,7])

# %%
a1d
# Out:
# array([5, 6, 7])

# %%
np.mean(a1d) #variance
# Out:
# np.float64(6.0)

# %%
np.var(a1d) #standard deviation manuualy
# Out:
# np.float64(0.6666666666666666)

# %%
np.std(a1d) #Built in methods standard deviation 4.35minutees video
# Out:
# np.float64(0.816496580927726)
