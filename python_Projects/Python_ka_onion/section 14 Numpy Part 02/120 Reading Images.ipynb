# %% [markdown]
# ## 120.Reading Images

# %%
import pandas as pd

# %%
import numpy as np

# %%
from matplotlib.image import imread

# %%
img_data = imread('new.jpeg')

# %%
img_data
# Out:
# array([[[162, 192, 228],
#         [162, 192, 228],
#         [162, 192, 228],
#         ...,
#         [170, 196, 231],
#         [170, 196, 231],
#         [170, 196, 231]],
#
#        [[162, 192, 228],
#         [162, 192, 228],
#         [162, 192, 228],
#         ...,
#         [170, 196, 231],
#         [170, 196, 231],
#         [170, 196, 231]],
#
#        [[162, 192, 228],
#         [162, 192, 228],
#         [162, 192, 228],
#         ...,
#         [170, 196, 231],
#         [170, 196, 231],
#         [170, 196, 231]],
#
#        ...,
#
#        [[217, 201, 186],
#         [216, 200, 185],
#         [215, 199, 184],
#         ...,
#         [ 34,  44,  79],
#         [ 32,  45,  79],
#         [ 32,  45,  79]],
#
#        [[218, 202, 187],
#         [217, 201, 186],
#         [216, 200, 185],
#         ...,
#         [ 34,  44,  79],
#         [ 32,  45,  80],
#         [ 32,  45,  80]],
#
#        [[219, 203, 188],
#         [218, 202, 187],
#         [217, 201, 186],
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.imshow(img_data)
plt.show()

# %%
img_data.shape
# Out:
# (1184, 864, 3)
