# %% [markdown]
# ## 114 Dot Product vs Matrix Manipulation

# %%
import pandas as pd

# %%
import numpy as np

# %%
np.random.seed(seed=0)
matrix_1 = np.random.randint(10,size=(4,3))
matrix_2 = np.random.randint(10,size=(4,3))

# %%
matrix_1
# Out:
# array([[5, 0, 3],
#        [3, 7, 9],
#        [3, 5, 2],
#        [4, 7, 6]], dtype=int32)

# %%
matrix_2
# Out:
# array([[8, 8, 1],
#        [6, 7, 7],
#        [8, 1, 5],
#        [9, 8, 9]], dtype=int32)

# %% [markdown]
# # Element wise multiplication kia hoti hai

# %%
matrix_1*matrix_1
# Out:
# array([[25,  0,  9],
#        [ 9, 49, 81],
#        [ 9, 25,  4],
#        [16, 49, 36]], dtype=int32)

# %%
matrix_1*matrix_2
# Out:
# array([[40,  0,  3],
#        [18, 49, 63],
#        [24,  5, 10],
#        [36, 56, 54]], dtype=int32)
