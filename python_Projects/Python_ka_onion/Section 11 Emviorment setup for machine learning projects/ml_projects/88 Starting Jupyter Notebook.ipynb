# %%
print('chao chao')
# Out:
# chao chao

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

print("Notebook ready!")
# Out:
# Notebook ready!

# %% [raw]
# HEADING/RAW
# #rgggdfgdfgdfdgdfgdfgdgdf

# %% [markdown]
# MARK DOWN
#
#
# dfgddfddgdfgdg
