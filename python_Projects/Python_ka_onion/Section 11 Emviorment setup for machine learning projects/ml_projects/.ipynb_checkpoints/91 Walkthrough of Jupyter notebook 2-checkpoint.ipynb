# %%
#91.Walkthrough of Jupytr notebook 2

# %% [markdown]
# mark dow in jupyter and code selections and different uses
#
# 📘 Markdown Cell Overview
# #91. Walkthrough of Jupytr notebook 2 — This is a level-1 heading, typically used to title a section.
#
# mark dow in jupyter and code selections and different uses — A brief description, likely introducing the purpose of the walkthrough.
#
# ✅ What Markdown Does in Jupyter
# Markdown in Jupyter is used for:
#
# Documentation: Explain code, add instructions, or summarize results.
#
# Formatting: Use headings, lists, bold/italic text, links, and images.
#
# Structure: Organize notebooks into readable sections for students, collaborators, or future reference.

# %% [markdown]
# #Shift + Enter to run cell

# %% [markdown]
# in order to select y to selcet code mode and M for markdown you have to click with mouse in tools section
