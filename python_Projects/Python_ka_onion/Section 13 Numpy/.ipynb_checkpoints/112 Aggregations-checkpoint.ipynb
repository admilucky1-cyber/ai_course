# %%
import pandas as pd

# %%
import numpy as np

# %%
a1d = np.array([1, 2, 3])

# %%
a1d
# Out:
# array([1, 2, 3])

# %%
a2d = np.array([[1, 2, 3], [4, 5, 6]])

# %%
a2d
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a3d = np.array([[[1,2,3,3],[4,5,6,5]],[[1,2,3,5],[7,8,9,6]]])

# %%
a3d
# Out:
# array([[[1, 2, 3, 3],
#         [4, 5, 6, 5]],
#
#        [[1, 2, 3, 5],
#         [7, 8, 9, 6]]])

# %% [markdown]
# # Agregations

# %%
a1d
# Out:
# array([1, 2, 3])

# %%
sum(a1d) #this is python methods::Slower
# Out:
# np.int64(6)

# %%
np.sum(a1d) #this is numpy ::faster
# Out:
# np.int64(6)

# %%
#Example
lambi_array = np.random.random(1000)

# %%
lambi_array.size
# Out:
# 1000

# %%
lambi_array[:20]
# Out:
# array([0.19844476, 0.57460081, 0.03521241, 0.84320187, 0.79080544,
#        0.07349873, 0.41103066, 0.41279182, 0.73077823, 0.54934309,
#        0.15114203, 0.29154367, 0.65571397, 0.75330917, 0.6106473 ,
#        0.39597806, 0.90476797, 0.3895364 , 0.23630232, 0.17997595])

# %%
# %timeit sum(lambi_array) #python sum
# %timeit np.sum(lambi_array) #Numpy sum
# Out:
# 73 μs ± 1.59 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
# 3.85 μs ± 278 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
np.max(a1d)
# Out:
# np.int64(3)

# %%
np.min(a1d)
# Out:
# np.int64(1)
