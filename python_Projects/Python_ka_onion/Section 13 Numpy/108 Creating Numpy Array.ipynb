# %% [markdown]
# # we will learn /Creating numpy arrays \

# %%
import pandas as pd

# %%
import numpy as np

# %%
test_array = np.array([1,2,3])

# %%
test_array
# Out:
# array([1, 2, 3])

# %%
#Zeros
#Ones
#randoms
ones = np.ones((2,3))

# %%
ones
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
type(ones)
# Out:
# numpy.ndarray

# %%
zeros = np.zeros((2,3))

# %%
zeros
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.]])

# %%
range_array = np.arange(0,10,2)   #A range to understand if u gets confusd

# %%
range_array
# Out:
# array([0, 2, 4, 6, 8])

# %%
#np.random.randint(start, stop, size=(3,5))
#np.random.randint(0, 10, size=(3,5))
random_matrix = np.random.randint(0, 10, size=(3,5)) # Manual Range start stop 3row and 5 columns

# %%
random_matrix
# Out:
# array([[7, 8, 7, 3, 3],
#        [8, 5, 2, 5, 5],
#        [5, 9, 6, 8, 1]], dtype=int32)

# %%
random_matrix.size
# Out:
# 15

# %%
random_matrix.shape
# Out:
# (3, 5)

# %%
random_matrix = np.random.rand(3,5)   #Auto range 0-1

# %%
random_matrix
# Out:
# array([[0.88618894, 0.01761955, 0.59571096, 0.58604598, 0.32849351],
#        [0.12976255, 0.55917385, 0.76025823, 0.55590697, 0.97962256],
#        [0.59042987, 0.81896996, 0.8327926 , 0.71155973, 0.0436773 ]])

# %%
random_matrix.sum()
# Out:
# np.float64(8.396212565166309)

# %% [markdown]
# # end of lecture
