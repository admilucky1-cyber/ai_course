# %% [markdown]
# # 111.Array Manipulation

# %%
import pandas as pd

# %%
import numpy as np

# %%
a1d = np.array([1, 2, 3])

# %%
a1d
# Out:
# array([1, 2, 3])

# %%
ones = np.ones((2,3))

# %%
ones
# Out:
# array([[1., 1., 1.],
#        [1., 1., 1.]])

# %%
a1d+ones #broad castng
# Out:
# array([[2., 3., 4.],
#        [2., 3., 4.]])

# %%
a2d = np.array([[1, 2, 3], [4, 5, 6]])

# %%
a2d
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
a3d = np.array([[[1,2,3,3],[4,5,6,5]],[[1,2,3,5],[7,8,9,6]]])

# %%
a3d
# Out:
# array([[[1, 2, 3, 3],
#         [4, 5, 6, 5]],
#
#        [[1, 2, 3, 5],
#         [7, 8, 9, 6]]])

# %% [markdown]
# # is a 2D NumPy array with two rows and three columns, containing floating-point numbers. Based on the surrounding page context — a Jupyter Notebook titled "111 Array Manipulation" — this array likely results from a slicing or broadcasting operation applied to a higher-dimensional array.
#
# # 📊 Likely Meaning in Context
# Given the notebook’s focus on array manipulation, this array could be:
#
# A slice from a 3D or 4D array, extracting a 2D matrix.
#
# A broadcasted result, where a smaller array was expanded to match the shape of another.
#
# A transformation output, such as reshaping or stacking.
#
# The repeated rows suggest either:
#
# A slice like array[:, :3] from a larger array with identical rows.
#
# A broadcasted row [2., 3., 4.] across two rows.
# # 🧑‍🏫 Teaching Tip (English + Roman Urdu)
# # English: This is a 2D array with 2 rows and 3 columns, possibly sliced or broadcasted from a larger array.
# # Roman Urdu: Ye ek 2D array hai jisme 2 rows aur 3 columns hain, shayad kisi bade array se slice ya broadcast hua hai.

# %%
a1d-ones  #subraction
# Out:
# array([[0., 1., 2.],
#        [0., 1., 2.]])

# %%
a1d*ones #multiplication
# Out:
# array([[1., 2., 3.],
#        [1., 2., 3.]])

# %%
t = a3d[:2,:2,:3]

# %%
a2d*t
# Out:
# array([[[ 1,  4,  9],
#         [16, 25, 36]],
#
#        [[ 1,  4,  9],
#         [28, 40, 54]]])

# %%
a1d/a2d
# Out:
# array([[1.  , 1.  , 1.  ],
#        [0.25, 0.4 , 0.5 ]])

# %%
a1d//a2d
# Out:
# array([[1, 1, 1],
#        [0, 0, 0]])

# %%
a1d**2
# Out:
# array([1, 4, 9])

# %%
np.square(a1d)
# Out:
# array([1, 4, 9])

# %%
a2d%2
# Out:
# array([[1, 0, 1],
#        [0, 1, 0]])

# %%
end of lecture 111 at 52:45sec
