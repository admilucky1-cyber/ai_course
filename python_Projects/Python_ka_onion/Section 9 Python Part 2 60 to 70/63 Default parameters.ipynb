# %%
#Parameter
#Argument

# %%
#let us suppose so you bunk lecture from your class and you go to simosa shop to eat some tell somsa wal bhi that you can use python to add cash 
#def adder():
#    x=6
#    y=4
#    print(x+y)
    #in this program tea seller say where i will find x and y if i have lots of them and i have to change x and y by going inside of program
    #so i must solve this issue

#adder()

                                        ##################ONE-1ST#############

# %%
#let us suppose so you bunk lecture from your class and you go to simosa shop to eat some tell somsa wal bhi that you can use python to add cash 
# code ka designer
#Parameter=it is code ky likhny waly ny #varibales# in function declaration
def adder(x,y):
    print(x+y)
    #in this program tea seller say where i will find x and y if i have lots of them and i have to change x and y by going inside of program
    #so i must solve this issue
    
    #canteeen owner
    #Argument = user jo values deta h variable or variables ko usy argument kehty h

adder(3,2) #output 5 #call invoke ,execute
adder(4,6) # output 10
adder(3,4) #otput 7

# %%
##63.Default Parameters 
###m dobara canteen owner bolta h yar ab mera recipt printer harab h mujhy recipt generate kr k deni h customer mang rahy h

# %%
#parameter positional
def recipt(name,amount):
    print(f"Hi, {name}, You paid {amount}, Thank You")


#OWNER
#Concept 1#Arguments {positIonal argument}
recipt('Jhony', 10)


#concept 2 #Keyword Argument
recipt(amount = 10,name = 'Sally')
# Out:
# Hi, Jhony, You paid 10, Thank You
# Hi, Sally, You paid 10, Thank You

# %%
#concept 3#FOR UNDERSTANDING AND PRACTICE FOR {DEFAULT VALUE }
#parameter positional

def recipt(name='Jhon',amount=10): #Default 
    print(f"Hi, {name}, You paid {amount}, Thank You")


#OWNER
#Arguments positonal argument
#recipt('Jhon', 10)    #1st practice
#recipt()                   2nd practices
recipt('Pinto', 30)  #last paractice ,{then Pinto will overide Jhon at output}
#this is my trial i did it to apply heheh
recipt('sandi', 100)
#Keyword Argument
#recipt(amount = 10,name = 'Sally')
recipt()
#####concept 3####### 
#Default Value we have change given recipt a value instead of giving argument or keyword argument
# Out:
# Hi, Pinto, You paid 30, Thank You
# Hi, sandi, You paid 100, Thank You
# Hi, Jhon, You paid 10, Thank You
