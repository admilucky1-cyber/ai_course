# %%
#66.Quality of Good Programmer

# %%
#Create odd or even number identifier

# %%
#practice one
def even(num):
  if num%2==0:
    return True
  elif num%2 != 0:
    return 'This is odd'
print(even(88))
print(even(23))
print(even(2))
#print(odd(22)) #this is to show  because we have to define function oterwise error arises
# Out:
# True
# This is odd
# True

# %%
#practice Two

def even(num):
  if num%2==0:
    return'This is even'
  else:
    return 'This is odd'
print(even(88))
print(even(23))
print(even(2))
#print(odd(22))
# Out:
# This is even
# This is odd
# This is even

# %%
#when you are writing  then make sure how to make shorter and comprehensive
###above code below do the same thing then you can find difference
#which is more reliable

def even(num):
     return num%2==0

print(even(22))
print(even(21))
# Out:
# True
# False
