# %%
#65. Doc String:

##Function should do one thing and one only
##A function must return something


def recipt(name='Jhon', amount=10):
    """
    recipt function creates recipt
    name: takes name is a string
    amount: takes amount is an integer
    amount is returned so that it can be used further
    """
    print(f"Hi, {name}, You paid {amount}, Thank you")
    return amount  #####v.important to show output after deduction of 2 dollars tax


#amount = recipt()
#tax = 2
#print(amount-tax) #yeha print function value de ni raha sirf dekha raha h #output will be non becuse if we do not use return function it acts like window shoping you go on a shop and from distance you observe  which things are available  this called so window shoping
###we can not assign print output  to other objects because print will show only as like window shopping

###     Doc String

help(recipt)
# Out:
# Help on function recipt in module __main__:
#
# recipt(name='Jhon', amount=10)
#     recipt function creates recipt
#     name: takes name is a string
#     amount: takes amount is an integer
#     amount is returned so that it can be used further

# %%
##other thing to learn### that doc string is different than commenting print result will also be different


##Function should do one thing and one only
##A function must return something


def recipt(name='Jhon', amount=10):
    
    #recipt function creates recipt # is placed for commenting
    #name: takes name is a string
    #amount: takes amount is an integer
    #amount is returned so that it can be used further
    
    print(f"Hi, {name}, You paid {amount}, Thank you")
    return amount  #####v.important to show output after deduction of 2 dollars tax


#amount = recipt()
#tax = 2
#print(amount-tax) #yeha print function value de ni raha sirf dekha raha h #output will be non becuse if we do not use return function it acts like window shoping you go on a shop and from distance you observe  which things are available  this called so window shoping
###we can not assign print output  to other objects because print will show only as like window shopping

###     Doc String

help(recipt)
# Out:
# Help on function recipt in module __main__:
#
# recipt(name='Jhon', amount=10)

# %%
#doc dindle method help 
#65. Doc String:

##Function should do one thing and one only
##A function must return something


def recipt(name='Jhon', amount=10):
    #cooments are not used to print help they remain unchange and uneffective of operation
    #recipt function creates recipt
    #name: takes name is a string
    #amount: takes amount is an integer
    #amount is returned so that it can be used further
    """
    recipt function creates recipt
    name: takes name is a string
    amount: takes amount is an integer
    amount is returned so that it can be used further
    """
    print(f"Hi, {name}, You paid {amount}, Thank you")
    return amount  #####v.important to show output after deduction of 2 dollars tax
    print(f"Hi, {name}, You paid {amount}, Thank you") # seconfd time not acceptable
    return amount #second time not acceptable

#amount = recipt()
#tax = 2
#print(amount-tax) #yeha print function value de ni raha sirf dekha raha h #output will be non becuse if we do not use return function it acts like window shoping you go on a shop and from distance you observe  which things are available  this called so window shoping
###we can not assign print output  to other objects because print will show only as like window shopping

###     Doc String

print(recipt.__doc__) #doc dindle method to get help
# Out:
# recipt function creates recipt
# name: takes name is a string
# amount: takes amount is an integer
# amount is returned so that it can be used further
