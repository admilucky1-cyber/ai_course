# %%
#Scope
#Rules

# %%
phone = 'iphone10_onRoad'

def parents_home():

    def my_home():
        return phone
    return my_home()


print(parents_home())
# Out:
# iphone10_onRoad

# %%
#1.starts with local (my_home)
#2.Then it looks into parents Local
#3.Then it looks in Global scope
#4.if not it make a plane it will check the Built in functions of python installed on the system

# %%
##Global Space
phone = 'iphone10_onRoad'

def parents_home():
    #parents Scope

    def my_home():
        #Local Scope
        return max   #4.if not it make a plane it will check the Built in functions of python installed on the system
    return my_home()


print(parents_home())
# Out:
# <built-in function max>
